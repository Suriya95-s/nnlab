# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-79f926069aaa> in <cell line: 1>()
# ----> 1 import tensorfkow as tf
#       2 print(tf._version_)
#
# ModuleNotFoundError: No module named 'tensorfkow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import tensorflow as tf
print(tf._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e3198a94b3aa> in <cell line: 2>()
#       1 import tensorflow as tf
# ----> 2 print(tf._version_)
#
# AttributeError: module 'tensorflow' has no attribute '_version_'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 84959, done.
# remote: Counting objects: 100% (587/587), done.
# remote: Compressing objects: 100% (263/263), done.
# remote: Total 84959 (delta 357), reused 535 (delta 319), pack-reused 84372
# Receiving objects: 100% (84959/84959), 597.53 MiB | 22.97 MiB/s, done.
# Resolving deltas: 100% (60846/60846), done.

# %%
# !pwd
# Out:
# /content
